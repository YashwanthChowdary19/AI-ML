# %% [markdown]
# ### <b>Problem 1: Banking System – Account Balance

# %%
class Account:
    def __init__(self, owner, balance):
        self.owner = owner
        balance = balance

    def deposit(amount):
        self.balance += amount
        print("Deposited:", amount)



This simulates a simple bank account where you can deposit money. Right now, the code has errors that prevent it from working correctly.

# %% [markdown]
# ### correct code

# %%
class Account:
    def __init__(self, owner, balance):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
        print("Deposited:", amount)

# %% [markdown]
# ### <b>Problem 2: Library Management – Book Checkout

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_checked_out = False

    def checkout():
        if self.is_checked_out:
            print("Already checked out")
        else:
            self.is_checked_out = True

This models a library book checkout system. Right now, it has errors that prevent it from functioning properly.

# %% [markdown]
# ### correct code

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        self.is_checked_out = False

    def checkout(self):
        if self.is_checked_out:
            print("Already checked out")
        else:
            self.is_checked_out = True

# %% [markdown]
# ### <b>👔 Problem 3: Employee Payroll – Salary Calculation

# %%
class Employee:
    company = "TechCorp"

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    @staticmethod
    def yearly_salary(self):
        return self.salary * 12



This models an employee payroll system where yearly salary needs to be calculated. Right now, the code has errors that break its functionality.

# %% [markdown]
# ### correct code

# %%
class Employee:
    company = "TechCorp"

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    
    def yearly_salary(self):
        return self.salary * 12

# %% [markdown]
# ### <b>Problem 4: E-commerce – Shopping Cart

# %%
class Cart:
    items = []

    def __init__(self):
        self.items = []
        
    
    def add_item(self, item):
        self.items.append(item)

# %% [markdown]
# ### correct code

# %% [markdown]
# ### <b>Problem 5: School System – Student Grades

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.grades = []

    def add_grade(self, grade):
        self.grades.append(grade)

    def average(self):
        return sum(self.grades) / len(self.grades)

# %% [markdown]
# ### correct code

# %%
class Student:
    def __init__(self, name):
        self.name = nclass Student:
    def __init__(self, name):
        self.name = name
        self.grades = []

    def add_grade(grade):
        self.grades.append(grade)

    def average(self):
        return sum(self.grades) / len(grades)ame
        self.grades = []

    def add_grade(self, grade):
        self.grades.append(grade)

    def average(self):
        return sum(self.grades) / len(self.grades)
